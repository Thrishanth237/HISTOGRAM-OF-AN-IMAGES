# %% [markdown]
# # EX NO:03
# # HISTOGRAM OF AN IMAGES
# **NAME** THRISHANTH
# **REG NO** 212224230291

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('parrot.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img,cmap ='gray')
plt.title('Original image')
plt.show()

# %%
plt.hist(img.ravel(),256,range=[0,256]);
plt.title('org img')
plt.show()

# %%
img_eg = cv2.equalizeHist(img)

# %%
plt.hist(img_eg.ravel(),256,range=[0,256]);
plt.title('Equalizeed Histogram')
plt.show()

# %%
plt.imshow(img_eg,cmap='gray')
plt.title('Org img')
plt.show()

# %%
img_c = cv2.imread('parrot.jpg',cv2.IMREAD_COLOR)
img_hsv = cv2.cvtColor(img_c,cv2.COLOR_BGR2HSV)

# %%
img_hsv[:,:,2] = cv2.equalizeHist(img_hsv[:,:,2])

# %%
img_eq = cv2.cvtColor(img_hsv,cv2.COLOR_HSV2BGR)
plt.imshow(img_eq[:,:,::-1]);
plt.title('EQUALIZED IMG');
plt.show()

# %%
plt.hist(img_hsv.ravel(),256,range=[0,256]);
plt.title('original image')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(img_c.ravel(),256,range=[0,256]);
plt.title('original image')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(img_eg.ravel(),256,range=[0,256]);
plt.title('equalized  image')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
